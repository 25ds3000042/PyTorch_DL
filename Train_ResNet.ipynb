# %% [markdown]
# <a href="https://colab.research.google.com/github/25ds3000042/PyTorch_DL/blob/main/Train_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pre-trained ResNet and teach it to recognize two types of images

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader

# %% [markdown]
# data used : CIFAR-10

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

train_data = datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=transform
)

train_loader = DataLoader(
    train_data,
    batch_size=32,
    shuffle=True
)
# Out:
#   2%|▏         | 3.15M/170M [00:35<31:10, 89.5kB/s]
